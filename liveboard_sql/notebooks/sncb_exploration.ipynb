# %%
import pandas as pd

calendar_dates = pd.read_csv("../data/raw/sncb/calendar_dates.txt")

calendar_dates.head()
# Out:
#        date  exception_type          service_id
# 0  20260514               1  gc:nmbssncb:000444
# 1  20260606               1  gc:nmbssncb:000444
# 2  20260607               1  gc:nmbssncb:000444
# 3  20260620               1  gc:nmbssncb:000444
# 4  20260621               1  gc:nmbssncb:000444

# %%
calendar = pd.read_csv("../data/raw/sncb/calendar.txt")
calendar.head()
# Out:
#    end_date  friday  monday  saturday          service_id  start_date  sunday  \
# 0  20261212       0       0         0  gc:nmbssncb:000000    20251220       0
# 1  20261212       0       0         0  gc:nmbssncb:000001    20251220       0
# 2  20261212       0       0         0  gc:nmbssncb:000002    20251220       0
# 3  20261212       0       0         0  gc:nmbssncb:000003    20251220       0
# 4  20261212       0       0         0  gc:nmbssncb:000004    20251220       0
#
#    thursday  tuesday  wednesday
# 0         0        0          0
# 1         0        0          0
# 2         0        0          0
# 3         0        0          0
# 4         0        0          0

# %%
routes = pd.read_csv("../data/raw/sncb/routes.txt")
routes.head()
# Out:
#   agency_id route_color  route_desc          route_id  \
# 0  nmbssncb      016AB3         NaN   gr:nmbssncb:100
# 1  nmbssncb      016AB3         NaN  gr:nmbssncb:1005
# 2  nmbssncb      016AB3         NaN  gr:nmbssncb:1010
# 3  nmbssncb      016AB3         NaN  gr:nmbssncb:1016
# 4  nmbssncb      016AB3         NaN  gr:nmbssncb:1021
#
#                  route_long_name route_short_name route_text_color  \
# 0         Gand-Dampoort -- Eeklo                L           FFFFFF
# 1         Bruxelles-Midi -- Genk               IC           FFFFFF
# 2     Bruxelles-Midi -- La Panne               IC           FFFFFF
# 3  Gand-Saint-Pierre -- Wetteren               IC           FFFFFF
# 4                  Genk -- Alost               IC           FFFFFF
#
#    route_type  route_url
# 0           2        NaN
# 1           2        NaN
# 2           2        NaN
# 3           2        NaN
# 4           2        NaN

# %%
stop_times = pd.read_csv("../data/raw/sncb/stop_times.txt")
stop_times.head()
# Out:
#   arrival_time departure_time  drop_off_type  pickup_type  \
# 0     17:22:00       17:23:00              0            0
# 1     17:27:00       17:27:00              0            1
# 2     14:11:00       14:11:00              1            0
# 3     14:24:00       14:24:00              1            1
# 4     14:31:00       14:36:00              0            0
#
#    shape_dist_traveled  stop_headsign                 stop_id  stop_sequence  \
# 0                  NaN            NaN   gs:nmbssncb:8813003_4             15
# 1                  NaN            NaN  gs:nmbssncb:8814001_13             16
# 2                  NaN            NaN     gs:nmbssncb:8200100              1
# 3                  NaN            NaN     gs:nmbssncb:8869054              2
# 4                  NaN            NaN   gs:nmbssncb:8866001_3              3
#
#                                              trip_id
# 0  gt:nmbssncb:88____:007::8200100:8814001:16:172...
# 1  gt:nmbssncb:88____:007::8200100:8814001:16:172...
# 2  gt:nmbssncb:88____:007::8200100:8814001:16:172...
# 3  gt:nmbssncb:88____:007::8200100:8814001:16:172...
# 4  gt:nmbssncb:88____:007::8200100:8814001:16:172...

# %%
stops = pd.read_csv("../data/raw/sncb/stops.txt")
stops.head()
# Out:
#    location_type parent_station platform_code  stop_code          stop_desc  \
# 0              1            NaN           NaN        NaN  NMBSSNCB  STATION
# 1              1            NaN           NaN        NaN  NMBSSNCB  STATION
# 2              1            NaN           NaN        NaN  NMBSSNCB  STATION
# 3              1            NaN           NaN        NaN  NMBSSNCB  STATION
# 4              1            NaN           NaN        NaN  NMBSSNCB  STATION
#
#                 stop_id   stop_lat  stop_lon   stop_name  stop_url  \
# 0  gs:nmbssncb:S8822533  50.944250  4.663010      Hambos       NaN
# 1  gs:nmbssncb:S8843406  50.528280  5.219680      Statte       NaN
# 2  gs:nmbssncb:S8861333  50.513500  4.675830        Mazy       NaN
# 3  gs:nmbssncb:S8811007  50.878510  4.378640  Schaerbeek       NaN
# 4  gs:nmbssncb:S8811106  50.867784  4.400963       Evere       NaN
#
#    wheelchair_boarding  zone_id
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN

# %%
transfers = pd.read_csv("../data/raw/sncb/transfers.txt")
transfers.head()
# Out:
#           from_stop_id  min_transfer_time           to_stop_id  transfer_type  \
# 0  gs:nmbssncb:8015577                300  gs:nmbssncb:8015577              2
# 1  gs:nmbssncb:8061676                300  gs:nmbssncb:8061676              2
# 2  gs:nmbssncb:8101003                300  gs:nmbssncb:8101003              2
# 3  gs:nmbssncb:8200102                300  gs:nmbssncb:8200102              2
# 4  gs:nmbssncb:8200129                300  gs:nmbssncb:8200129              2
#
#   from_trip_id to_trip_id
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN

# %%
translations = pd.read_csv("../data/raw/sncb/translations.txt")
translations.head()
# Out:
#   table_name field_name  record_id  record_sub_id           field_value  \
# 0      stops  stop_name        NaN            NaN               Beverlo
# 1      stops  stop_name        NaN            NaN              Messancy
# 2      stops  stop_name        NaN            NaN                Mérode
# 3      stops  stop_name        NaN            NaN  Frankfurt Flugh (DE)
# 4      stops  stop_name        NaN            NaN              Merchtem
#
#   language           translation
# 0       de               Beverlo
# 1       de              Messancy
# 2       de       Merode / Mérode
# 3       de  Frankfurt Flugh (DE)
# 4       de              Merchtem

# %%
trips = pd.read_csv("../data/raw/sncb/trips.txt")
trips.head()
# Out:
#    bikes_allowed  block_id  direction_id          route_id  \
# 0            NaN     76085           NaN  gr:nmbssncb:1370
# 1            NaN     76092           NaN  gr:nmbssncb:1370
# 2            NaN     76099           NaN  gr:nmbssncb:1370
# 3            NaN     76106           NaN  gr:nmbssncb:1370
# 4            NaN     76114           NaN  gr:nmbssncb:1370
#
#            service_id  shape_id       trip_headsign  \
# 0  gc:nmbssncb:000070       NaN  La Louvière-Centre
# 1  gc:nmbssncb:000070       NaN  La Louvière-Centre
# 2  gc:nmbssncb:000070       NaN  La Louvière-Centre
# 3  gc:nmbssncb:000070       NaN  La Louvière-Centre
# 4  gc:nmbssncb:000070       NaN  La Louvière-Centre
#
#                                              trip_id  trip_short_name  \
# 0  gt:nmbssncb:BBUS__:049::8882206:8882107:2:1729...             3417
# 1  gt:nmbssncb:BBUS__:049::8882206:8882107:2:1829...             3418
# 2  gt:nmbssncb:BBUS__:049::8882206:8882107:2:1929...             3419
# 3  gt:nmbssncb:BBUS__:049::8882206:8882107:2:2029...             3420
# 4  gt:nmbssncb:BBUS__:049::8882206:8882107:2:2129...             3421
#
#    wheelchair_accessible
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
# Drop e,mpty columns from the DataFrames

def drop_empty_columns(df):
    empty_cols = df.columns[df.isnull().all()]
    return df.drop(columns=empty_cols)

stop_times = drop_empty_columns(stop_times)
routes = drop_empty_columns(routes)
stops = drop_empty_columns(stops)
trips = drop_empty_columns(trips)
translations = drop_empty_columns(translations)

# %%
import sqlite3

conn = sqlite3.connect("../data/railwaypulse.db")

cursor = conn.cursor()

# Create the calendar_dates table if it doesn't exist
cursor.execute("""
    CREATE TABLE IF NOT EXISTS calendar_dates (
        service_id     TEXT NOT NULL,
        date           TEXT NOT NULL,
        exception_type INTEGER NOT NULL,
        PRIMARY KEY (service_id, date)
    )
""")
conn.commit()

calendar_dates.to_sql("calendar_dates", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the calendar table if it doesn't exist
cursor.execute("""
    CREATE TABLE IF NOT EXISTS calendar (
        service_id   TEXT NOT NULL,
        monday       INTEGER NOT NULL,
        tuesday      INTEGER NOT NULL,
        wednesday    INTEGER NOT NULL,
        thursday     INTEGER NOT NULL,
        friday       INTEGER NOT NULL,
        saturday     INTEGER NOT NULL,
        sunday       INTEGER NOT NULL,
        start_date   TEXT NOT NULL,
        end_date     TEXT NOT NULL,
        PRIMARY KEY (service_id)
    )
""")
conn.commit()

calendar.to_sql("calendar", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the routes table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS routes (
        route_id     TEXT NOT NULL,
        agency_id    TEXT,
        route_short_name TEXT,
        route_long_name  TEXT,
        route_type   INTEGER NOT NULL,
        route_color  TEXT,
        route_text_color TEXT,
        PRIMARY KEY (route_id)
    )
""")
conn.commit()

routes.to_sql("routes", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the stop_times table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS stop_times (
        trip_id       TEXT NOT NULL,
        arrival_time  TEXT NOT NULL,
        departure_time TEXT NOT NULL,
        drop_off_type INTEGER,
        pickup_type   INTEGER,
        stop_id       TEXT NOT NULL,
        stop_sequence INTEGER NOT NULL,
        PRIMARY KEY (trip_id, stop_sequence)
    )
""")
conn.commit()

stop_times.to_sql("stop_times", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the stops table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS stops (
        stop_id       TEXT NOT NULL,
        stop_name     TEXT NOT NULL,
        stop_lat      REAL NOT NULL,
        stop_lon      REAL NOT NULL,
        location_type INTEGER NOT NULL,
        parent_station TEXT,
        platform_code TEXT,
        stop_desc      TEXT,
        PRIMARY KEY (stop_id)
    )
""")
conn.commit()

stops.to_sql("stops", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the transfers table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS transfers (
        from_stop_id  TEXT NOT NULL,
        to_stop_id    TEXT NOT NULL,
        transfer_type INTEGER NOT NULL,
        min_transfer_time INTEGER,
        from_trip_id  TEXT,
        to_trip_id    TEXT,
        PRIMARY KEY (from_stop_id, to_stop_id)
    )
""")
conn.commit()

transfers.to_sql("transfers", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the trips table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS trips (
        route_id      TEXT NOT NULL,
        service_id    TEXT NOT NULL,
        trip_id       TEXT NOT NULL,
        trip_headsign TEXT,
        block_id      TEXT,
        bikes_allowed INTEGER,
        wheelchair_accessible INTEGER,
        trip_short_name TEXT,
        PRIMARY KEY (trip_id)
    )
""")
conn.commit()

trips.to_sql("trips", conn, if_exists="append", index=False)
conn.commit()

# %%
# Create the translations table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS translations (
        table_name    TEXT NOT NULL,
        field_name    TEXT NOT NULL,
        field_value   TEXT NOT NULL,
        language      TEXT NOT NULL,
        translation   TEXT NOT NULL,
        PRIMARY KEY (table_name, field_name, field_value, language)
    )
""")
conn.commit()

translations.to_sql("translations", conn, if_exists="append", index=False)
conn.commit()

# %%
cursor.execute("SELECT * FROM translations LIMIT 5")
print(cursor.fetchall())
# Out:
# [('stops', 'stop_name', 'Beverlo', 'de', 'Beverlo'), ('stops', 'stop_name', 'Messancy', 'de', 'Messancy'), ('stops', 'stop_name', 'Mérode', 'de', 'Merode / Mérode'), ('stops', 'stop_name', 'Frankfurt Flugh (DE)', 'de', 'Frankfurt Flugh (DE)'), ('stops', 'stop_name', 'Merchtem', 'de', 'Merchtem')]

# %%
"""
Relations between tables:

calendar_dates - calendar = service_id
calendar_dates - trips = service_id
stop_times - trips = trip_id
stop_times - stops = stop_id
trips - routes = route_id
stops.stop_name = translations.field_value
stops.stop_id = transfers.from_stop_id & transfers.to_stop_id
stops.trip_id = transfers.from_trip_id & transfers.to_trip_id
"""
# Out:
# '\nRelations between tables:\n\ncalendar_dates - calendar = service_id\ncalendar_dates - trips = service_id\nstop_times - trips = trip_id\nstop_times - stops = stop_id\ntrips - routes = route_id\nstops.stop_name = translations.field_value\nstops.stop_id = transfers.from_stop_id & transfers.to_stop_id\nstops.trip_id = transfers.from_trip_id & transfers.to_trip_id\n'

# %%
conn.close()
